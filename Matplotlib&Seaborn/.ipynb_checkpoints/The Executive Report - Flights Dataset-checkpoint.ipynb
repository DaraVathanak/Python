# %% [markdown]
# # The Executive Report - Flights Dataset
# ##### Dataset: sns.load_dataset('flights')
# ##### Goal: Take raw historical flight data and polish it into a presentation-ready graphic.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = sns.load_dataset('flights') 
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ##### Themes & Contexts: Apply sns.set_style('whitegrid') to give it a clean background, and sns.set_context('talk') to automatically scale up the fonts for a presentation slide.
# ##### Color Palettes: Pivot the dataset into a matrix (months vs. years) and plot a heatmap. Use sns.color_palette("Blues", as_cmap=True) so the colors intuitively map from light (few passengers) to dark (many passengers).
# ##### Advanced Matplotlib Formatting: Plot a line chart of average passengers per year.
# ##### Rotate the X-axis labels (years) by 45 degrees so they are perfectly legible.
# ##### Use ax.set_ylim(0, 500) to force the Y-axis to start at zero instead of floating.
# ##### Use ax.annotate() to draw an arrow pointing to the year 1960 with the text: "Introduction of Commercial Jets".
# ##### Exporting: Run plt.savefig('executive_flight_report.png', dpi=300, bbox_inches='tight') to save the final, high-resolution masterpiece to their computer.Explain each of the graphs in details(both Khmer and English)

# %%
sns.set_style('whitegrid')
sns.set_context('talk')

pivot = df.pivot_table(
    index='month',
    columns='year',
    values='passengers',
    observed=False
)

blue_palette = sns.color_palette("Blues", as_cmap=True)

yearly_avg = df.groupby('year')['passengers'].mean().reset_index()

fig, axes = plt.subplots(1, 2, figsize=(22, 8))

sns.heatmap(
    pivot,
    cmap=blue_palette,
    linewidths=0.5,
    cbar_kws={'label': 'Passengers'},
    ax=axes[0]
)

axes[0].set_title("Monthly Airline Passengers by Year")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Month")
axes[0].tick_params(axis='x', rotation=45)

ax = axes[1]

sns.lineplot(
    data=yearly_avg,
    x='year',
    y='passengers',
    marker='o',
    linewidth=3,
    ax=ax
)

ax.set_title("Average Passengers per Year")
ax.set_xlabel("Year")
ax.set_ylabel("Average Passengers")
ax.tick_params(axis='x', rotation=45)
ax.set_ylim(0, 500)

ax.annotate(
    "Introduction of Commercial Jets",
    xy=(
        1960,
        yearly_avg.loc[
            yearly_avg['year'] == 1960,
            'passengers'
        ].values[0]
    ),
    xytext=(1955, 450),
    arrowprops=dict(facecolor='black', shrink=0.05)
)

plt.tight_layout()
plt.savefig('executive_flight_report.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### This graph tells a story about airline travel from 1949 to 1960.At first, there were fewer passengers, but every year more people started flying. The busiest months were usually July and August, shown by the darker colors.The line graph also shows a clear rise in average passengers each year. By 1960, air travel became much more popular, helped by the introduction of commercial jets.In simple words: air travel kept growing every year, especially during summer months.
# ##### ក្រាហ្វនេះប្រាប់អំពីការធ្វើដំណើរតាមយន្តហោះពីឆ្នាំ 1949 ដល់ 1960។ដំបូងមានអ្នកដំណើរតិចប៉ុន្តែរៀងរាល់ឆ្នាំអ្នកដំណើរបានកើនឡើង។ខែដែលមានអ្នកដំណើរច្រើនជាងគេភាគច្រើនគឺ July និង August ដែលបង្ហាញដោយពណ៌ខ្មៅជាង។ក្រាហ្វខ្សែក៏បង្ហាញថាចំនួនអ្នកដំណើរមធ្យមកើនឡើងជារៀងរាល់ឆ្នាំ។ដល់ឆ្នាំ 1960 ការហោះហើរកាន់តែពេញនិយមដោយសារការចាប់ផ្តើមប្រើ commercial jets។និយាយឱ្យងាយយល់៖ ការធ្វើដំណើរតាមយន្តហោះកើនឡើងរៀងរាល់ឆ្នាំជាពិសេសនៅរដូវក្តៅ។
