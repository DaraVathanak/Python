# %% [markdown]
# # The Climate Sensor Grid Analyzer

# %% [markdown]
# ##### The Scenario: You are a climate data scientist. You have been handed a massive dataset from a satellite grid. To load the .npy file use np.load(“...”). The data is a 3D NumPy array structured as (Latitude, Longitude, Days), and the values inside represent the daily peak temperature in Celsius. You need to clean, analyze, and transform this data using only NumPy operations.

# %% [markdown]
# ##### Creating Arrays & Attributes: You load the provided climate dataset. You must inspect .shape, .ndim, and .dtype to understand how the geographical coordinates and the 31 days of the month are structured. Because you will be calculating temperature anomalies later, you also need to create a blank "baseline grid" of the exact same geographical dimensions using np.zeros().

# %%
import numpy as np
data = np.load("climate_data.npy")
print("Shape:", data.shape)
print("Dimensions:", data.ndim)
print("Data type:", data.dtype)
baseline = np.zeros(data.shape[:2])
# Out:
# Shape: (180, 360, 31)
# Dimensions: 3
# Data type: float64

# %% [markdown]
# ### Indexing, Slicing & Masking:

# %% [markdown]
# ##### Slicing: The dataset covers the whole globe, but you only want to analyze a specific drought-prone region. Crop the data to specific latitude and longitude coordinates (e.g., climate_data[20:50, 70:120, :]).

# %%
import numpy as np
data = np.load("climate_data.npy")
region = data[20:50, 70:120, :]
print(region.shape)
# Out:
# (30, 50, 31)

# %% [markdown]
# ##### Indexing: Isolate a "snapshot" of the entire grid for exactly Day 15 to see a cross-section of global temperatures on that specific day.

# %%
import numpy as np
data = np.load("climate_data.npy")
day15 = data[:, :, 14]
print(day15.shape)
# Out:
# (180, 360)

# %% [markdown]
# ##### Masking: Data cleaning is required. A sensor glitch caused several locations to record impossible temperatures of -99°C. Create a boolean mask to find all instances of -99 and replace them with np.nan (Not a Number) so they don't skew your later calculations.

# %%
import numpy as np
data = np.load("climate_data.npy")
mask = data == -99.0
data[mask] = np.nan
print(np.sum(mask))
# Out:
# 4994

# %% [markdown]
# ### Vectorization, Broadcasting & Ufuncs:

# %% [markdown]
# ##### Broadcasting: Your American stakeholders need the data in Fahrenheit. Convert the entire 3D array from Celsius to Fahrenheit in a single mathematical step ((data * 9/5) + 32) without writing a single for loop.

# %%
import numpy as np
data = np.load("climate_data.npy").astype(float)
data[data == -99.0] = np.nan
data_f = (data * 9/5) + 32
print(data_f[0, 0, :])
# Out:
# [ 39.74 107.24  81.68  66.02  14.18  14.18   2.84  97.34  66.38  78.8
#   -1.66 109.4   93.38  20.84  17.24  17.42  31.64  57.38  46.58  30.02
#   67.64  12.38  30.2   38.84  49.28  87.8   19.4   56.12  65.3    1.4
#   67.1 ]

# %% [markdown]
# #####  Ufuncs: To model a specific heat-stress index, apply a non-linear transformation to the temperature values using np.exp() and np.log() across the entire grid simultaneously.

# %%
import numpy as np
data = np.load("climate_data.npy").astype(float)
data[data == -99.0] = np.nan
stress = np.log1p(np.exp(data / 40.0))
print(stress[0, 0, :5])
# Out:
# [0.74834102 1.34635701 1.09651527 0.95704841 0.57703475]

# %% [markdown]
# ###  Math & Stats:

# %% [markdown]
# ##### Find the absolute highest and lowest valid temperatures recorded anywhere on the grid during the month (np.nanmax, np.nanmin).

# %%
import numpy as np
data = np.load("climate_data.npy").astype(float)
data[data == -99.0] = np.nan
max_temp = np.nanmax(data)
min_temp = np.nanmin(data)
print("Max temperature:", max_temp)
print("Min temperature:", min_temp)
# Out:
# Max temperature: 45.0
# Min temperature: -20.0

# %% [markdown]
# ##### Calculate the average temperature for each specific sensor location across the entire month (using np.nanmean across the "Days" axis). This will collapse your 3D array into a 2D map showing the baseline climate for each coordinate!

# %%
import numpy as np
data = np.load("climate_data.npy").astype(float)
data[data == -99.0] = np.nan
baseline_map = np.nanmean(data, axis=2)
print(baseline_map.shape)
print(baseline_map[0, 0,:])
# Out:
# (180, 360)
# [ 8.85483871 11.33225806 12.28387097 12.03225806 10.01612903 10.30322581
#  12.23225806 16.19354839 20.22903226  9.25806452  8.74516129 10.21935484
#  15.92258065 12.61290323 11.92258065 15.75666667 19.78064516 16.47741935
#  11.20645161  5.58387097  7.05806452  9.56129032  9.08709677 13.57666667
#  14.6483871  15.32903226 13.06451613  7.43870968  8.16129032 10.69
#   9.98387097 10.84516129 16.23870968 14.62580645 13.91612903 13.78709677
#  14.11290323 17.34193548 13.80967742 13.38064516 10.82903226  6.81935484
#  13.8        16.42903226 10.31666667 11.0483871  16.13548387 16.18
#  10.3483871   9.74516129 13.3516129   9.9        15.85483871 15.61612903
#  11.4516129   9.30322581  8.98709677 13.72580645  9.78387097 17.63870968
#  14.40967742 12.37741935 10.49032258 13.9516129   7.67419355 12.89677419
#  11.50967742 17.32580645 13.20322581 14.4483871  15.01935484 10.59677419
#  17.16129032  9.36451613  9.25483871 10.04193548 12.37419355  8.27419355
#  10.81935484 14.7516129  17.74193548 16.19354839  9.01935484 12.22903226
#   9.11935484 14.61290323  7.41290323 10.39032258 15.0516129  10.75806452
#  16.68387097 12.71333333 11.62258065  9.42258065 16.05483871 17.81290323
#  16.85806452  8.16666667  7.76333333 14.11612903 10.43548387 15.08064516
#  10.63225806  9.83548387  8.23548387 11.9516129  10.86774194 16.51290323
#  11.21935484 13.99677419 14.93870968 15.30967742 16.47419355 11.17096774
#   4.81612903 17.09032258  8.54193548 11.03548387  8.00645161 14.82903226
#  13.6516129  12.97419355  9.54516129 12.18387097  9.43870968 19.17096774
#  12.81290323  4.92903226 11.33225806  9.78387097 17.80967742 12.
#   8.67096774 11.73225806 10.81935484 10.79354839 12.89032258 12.51290323
#  10.91612903 13.97419355 12.1         5.33548387  8.63548387 15.25806452
#  14.05806452 10.43225806  9.3516129  16.90645161 13.         18.46451613
#  15.98387097 11.70322581  8.64333333 13.78387097  5.79677419 13.04666667
#  12.02903226  6.12580645 12.35483871 18.51612903 14.13666667 11.41290323
#  14.7483871  10.15483871  7.87096774 13.69677419  9.76451613 18.18387097
#   9.03548387 16.71290323  7.65806452 12.29677419 14.40967742 14.56129032
#  11.35333333  8.61290323 13.94516129 13.23225806  7.90645161 17.69354839
#  11.00322581 10.62258065 13.69677419 10.47666667 10.72258065 19.83548387
#  12.07096774 11.26451613 12.03225806 14.50322581 11.36333333 11.2483871
#  17.36774194 12.20645161 10.18709677 12.96774194 10.06774194 11.06774194
#   9.21612903  8.00322581 10.21290323 14.79677419 15.93225806 13.50967742
#   8.3483871  15.09354839 13.20322581 14.53870968 15.5516129   9.1516129
#  13.56774194  8.91612903 12.47741935 11.23333333 13.71612903 10.29032258
#  13.01612903 11.67096774 15.39032258  9.20645161 11.95806452 12.72258065
#  11.21290323 10.38064516 12.37419355 13.19666667 10.93225806 15.34193548
#   7.82580645 12.12903226 16.31935484 14.25806452 12.54516129 15.85483871
#   5.50322581 11.77096774 10.23225806 13.9         9.59032258  5.25806452
#  12.43870968 11.74193548 10.18387097 14.43548387 11.52580645 12.64193548
#  10.23548387 15.8        12.48064516 11.61935484 10.11612903  5.62903226
#  11.45483871  7.52580645 10.40645161 10.70645161 10.5516129  13.0483871
#  15.48709677 10.49677419 13.18064516 14.21290323 11.35806452  9.19666667
#   5.13225806 10.9516129  13.66129032  9.82903226 14.6        11.83548387
#  14.09032258  5.9        13.25806452 12.13870968 13.26129032 14.6483871
#  13.3516129  16.86774194 10.13225806  5.95806452 10.08387097 12.28387097
#   5.02580645 11.83548387 11.27096774 11.8         8.24       16.66774194
#  14.14193548 12.27096774  6.83225806 13.50333333 12.55806452 12.31935484
#  20.11935484 10.29677419 17.03548387 13.71290323 10.2        15.00967742
#  12.41935484 18.15483871 12.84193548  6.38387097 10.19354839 18.75806452
#   6.82258065 10.89354839 12.51333333  8.0516129  10.62580645  8.91935484
#  12.64        9.         12.89354839 11.32903226 18.50322581 15.97741935
#  10.35        7.90645161 10.98709677 12.98064516 16.06129032  9.48387097
#  16.51935484 12.25483871  6.12903226 14.10322581 11.29032258  9.21935484
#  12.66451613 11.23225806 17.00645161 11.20645161 18.34193548 13.6516129
#  13.35806452 16.51935484  6.17741935 13.01935484 15.42258065 15.8
#  16.69677419 19.4516129   8.46774194 12.37741935 11.24333333 11.09032258
#  13.55806452 14.73548387 11.89032258  7.95483871 10.26774194 12.73225806
#  14.52258065 18.66774194 12.73548387 13.2516129  15.42258065 16.60645161]
